# %% [markdown]
# Exercise requeriments:
#
# Cell 1 (rendered as Markdown): The title should be "My Jupyter Notebook on IBM Data Science Experience", in H1 header styling. The title does not need to be centered.
# Cell 2 (rendered as Markdown): Your name, in bold characters. In the line below your name, write your current or desired occupation in regular font.
# Cell 3 (rendered as Markdown): In italic formatting, write one or two sentences about why you are interested in data science. For example, you can start your first sentence with "I am interested in data science because ...".
# Cell 4 (rendered as Markdown): In H3 header styling, explain in a short sentence what your code is supposed to do in Cell 5.
# Cell 5 (code cell): Your code, as described in Cell 4. It must be executed and must display an output. Try to keep the code simple (it can even be "1 + 1").
# Cell 6 (rendered as Markdown): Using Markdown or HTML, this cell must include at least 3 of the following: horizontal rule, bulleted list, numbered list, tables, hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough.

# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# __Xavier Martinez__
# Civil Engineer

# %% [markdown]
# *I am interested in learning data science to understand how can I apply it in Civil Engineering.*
# *Also, I am interested in Data Science in the finance sector, particularly in Quant Finance.*

# %% [markdown]
# ### The code below runs a few basic tasks: printing text in screen, simple calculations, genaration of an array of random numbers, and ploting a functions.
# ### The code has been developed in Python, and uses the NumPy and matplotlib libraries.

# %%
# print text in the screen
print ("Hello Data Scinetists colleagues.")
# Out:
# Hello Data Scinetists colleagues.

# %%
# simple calculations
3 + 4 * 2
# Out:
# 11

# %%
# working with NumPy arrays
import numpy as np
rn = np.random.standard_normal(100)
rn[:10]
# Out:
# array([ 1.16266597, -0.25959536, -1.46862012, -1.33490299, -0.79112685,
#        -0.04318599,  1.72873707, -0.67587214, -1.65332485,  1.06639765])

# %%
# plotting a line graph
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(rn.cumsum())
plt.grid(True)

# %%
# plotting a a scatter plot
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2 # 0 to 15 point radiuses

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ### Sumary
# *****
#
# #### The code in the cells above have shown how:
#     1. Print text on the screen
#     2. Execute a simple calculation
#     3. Generate an array of random numbers
#     4. Create two types op plots
#
# #### Two libraries have been used:
#     * NumPy
#     * matplotlib
#
#    The function `rand` from the NumPy library has been use to generate the random numbers:
#           area = np.pi * (15 * `np.random.rand`(N))**2
#  _____
